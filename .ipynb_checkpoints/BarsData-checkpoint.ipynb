# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem

# %%
bars_metadata = "bars_data_output.csv"

# %%
bars_metadata = pd.read_csv(bars_metadata)
bars_metadata
# Out:
#                          id                                      alias  \
# 0    oT08T3Vpn1I7jDmrBBRMTw           house-of-prime-rib-san-francisco
# 1    f-m7-hyFzkf0HSEeQ2s-9A      fog-harbor-fish-house-san-francisco-2
# 2    ttarnopezxmp2ROB1N2PaA                         nopa-san-francisco
# 3    KkAVX3Wb7E3lP5F_f_8pXg        liholiho-yacht-club-san-francisco-2
# 4    mSMZJj2pFvttWLpcDmgrEA       tonys-pizza-napoletana-san-francisco
# ..                      ...                                        ...
# 995  n-EK1TJZhfQYJ1gc-72iJw                   beachers-san-francisco-6
# 996  obbj78gbuT-mSwe5i5G8ng  san-francisco-new-years-eve-san-francisco
# 997  yQ7xPB632J5a9NYtDKDl7g               jp-morgan-club-san-francisco
# 998  GvLEvVvNAN7v1ePyoFFKnA                      bar-217-san-francisco
# 999  aUeBNa2W1GXjAeXmSM4nHw        bristol-bar-and-grill-san-francisco
#
#                             name  \
# 0             House of Prime Rib
# 1          Fog Harbor Fish House
# 2                           Nopa
# 3            Liholiho Yacht Club
# 4        Tony's Pizza Napoletana
# ..                           ...
# 995                     Beachers
# 996  San Francisco New Years Eve
# 997               JP Morgan Club
# 998                      Bar 217
# 999          Bristol Bar & Grill
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/HLrjaM...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/5wuA-0...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/16cGmQ...      False
# 3    https://s3-media2.fl.yelpcdn.com/bphoto/dHWRdc...      False
# 4    https://s3-media1.fl.yelpcdn.com/bphoto/6jgpZM...      False
# ..                                                 ...        ...
# 995                                                NaN      False
# 996  https://s3-media2.fl.yelpcdn.com/bphoto/aIAF5V...      False
# 997                                                NaN      False
# 998  https://s3-media3.fl.yelpcdn.com/bphoto/yeBwkF...      False
# 999  https://s3-media4.fl.yelpcdn.com/bphoto/yKVbij...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/house-of-prime-rib-sa...          7211
# 1    https://www.yelp.com/biz/fog-harbor-fish-house...          6088
# 2    https://www.yelp.com/biz/nopa-san-francisco?ad...          5078
# 3    https://www.yelp.com/biz/liholiho-yacht-club-s...          2423
# 4    https://www.yelp.com/biz/tonys-pizza-napoletan...          5089
# ..                                                 ...           ...
# 995  https://www.yelp.com/biz/beachers-san-francisc...             1
# 996  https://www.yelp.com/biz/san-francisco-new-yea...             1
# 997  https://www.yelp.com/biz/jp-morgan-club-san-fr...             1
# 998  https://www.yelp.com/biz/bar-217-san-francisco...             1
# 999  https://www.yelp.com/biz/bristol-bar-and-grill...            12
#
#                                             categories  rating  \
# 0    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 1    [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2    [{'alias': 'newamerican', 'title': 'American (...     4.0
# 3    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# ..                                                 ...     ...
# 995               [{'alias': 'bars', 'title': 'Bars'}]     5.0
# 996               [{'alias': 'pubs', 'title': 'Pubs'}]     5.0
# 997  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     5.0
# 998  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     5.0
# 999  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     2.0
#
#                    transactions  ...   latitude   longitude  \
# 0                            []  ...  37.793380 -122.422500
# 1    ['restaurant_reservation']  ...  37.809041 -122.410233
# 2                  ['delivery']  ...  37.774830 -122.437460
# 3                  ['delivery']  ...  37.788180 -122.414580
# 4                  ['delivery']  ...  37.800332 -122.409054
# ..                          ...  ...        ...         ...
# 995                          []  ...        NaN         NaN
# 996                          []  ...  37.797760 -122.431910
# 997                          []  ...  37.767920 -122.387390
# 998                          []  ...  37.797195 -122.406120
# 999                          []  ...  37.806435 -122.418068
#
#      location.address1  location.address2  location.address3  location.city  \
# 0    1906 Van Ness Ave                NaN                NaN  San Francisco
# 1      The Embarcadero          Ste A-202                NaN  San Francisco
# 2    560 Divisadero St               None                NaN  San Francisco
# 3        871 Sutter St                NaN                NaN  San Francisco
# 4     1570 Stockton St                NaN                NaN  San Francisco
# ..                 ...                ...                ...            ...
# 995                NaN                NaN                NaN  San Francisco
# 996      1980 Union St                NaN                NaN  San Francisco
# 997     1 Warriors Way                NaN               None  San Francisco
# 998    217 Columbus St               None                NaN  San Francisco
# 999  1300 Columbus Ave                NaN                NaN  San Francisco
#
#     location.zip_code location.country location.state  \
# 0             94109.0               US             CA
# 1             94133.0               US             CA
# 2             94117.0               US             CA
# 3             94109.0               US             CA
# 4             94133.0               US             CA
# ..                ...              ...            ...
# 995               NaN               US             CA
# 996           94123.0               US             CA
# 997           94158.0               US             CA
# 998           94133.0               US             CA
# 999           94133.0               US             CA
#
#                                        display_address
# 0     ['1906 Van Ness Ave', 'San Francisco, CA 94109']
# 1    ['The Embarcadero', 'Ste A-202', 'San Francisc...
# 2     ['560 Divisadero St', 'San Francisco, CA 94117']
# 3         ['871 Sutter St', 'San Francisco, CA 94109']
# 4      ['1570 Stockton St', 'San Francisco, CA 94133']
# ..                                                 ...
# 995                              ['San Francisco, CA']
# 996       ['1980 Union St', 'San Francisco, CA 94123']
# 997      ['1 Warriors Way', 'San Francisco, CA 94158']
# 998     ['217 Columbus St', 'San Francisco, CA 94133']
# 999   ['1300 Columbus Ave', 'San Francisco, CA 94133']
#
# [1000 rows x 24 columns]

# %%
bars_metadata.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'latitude', 'longitude',
#        'location.address1', 'location.address2', 'location.address3',
#        'location.city', 'location.zip_code', 'location.country',
#        'location.state', 'display_address'],
#       dtype='object')

# %%
rating_count = bars_metadata['rating'].value_counts()

# %%
review_count
# Out:
# 1000

# %%
list(bars_metadata.columns)
new_columns = [
    'name',
    'review_count',
    'categories',
    'rating',
]

# %%
categories_data = bars_metadata[new_columns]

# %%
categories_data
# Out:
#                             name  review_count  \
# 0             House of Prime Rib          7211
# 1          Fog Harbor Fish House          6088
# 2                           Nopa          5078
# 3            Liholiho Yacht Club          2423
# 4        Tony's Pizza Napoletana          5089
# ..                           ...           ...
# 995                     Beachers             1
# 996  San Francisco New Years Eve             1
# 997               JP Morgan Club             1
# 998                      Bar 217             1
# 999          Bristol Bar & Grill            12
#
#                                             categories  rating
# 0    [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 1    [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2    [{'alias': 'newamerican', 'title': 'American (...     4.0
# 3    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# ..                                                 ...     ...
# 995               [{'alias': 'bars', 'title': 'Bars'}]     5.0
# 996               [{'alias': 'pubs', 'title': 'Pubs'}]     5.0
# 997  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     5.0
# 998  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     5.0
# 999  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     2.0
#
# [1000 rows x 4 columns]

# %%
categories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
# name            1000 non-null object
# review_count    1000 non-null int64
# categories      1000 non-null object
# rating          1000 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
categories_data_explode = categories_data.assign(categories = categories_data.categories
                         .str.split(', ')).explode('categories')

# %%
categories_data_explode
# Out:
#                     name  review_count                          categories  \
# 0     House of Prime Rib          7211           [{'alias': 'tradamerican'
# 0     House of Prime Rib          7211  'title': 'American (Traditional)'}
# 0     House of Prime Rib          7211                   {'alias': 'steak'
# 0     House of Prime Rib          7211             'title': 'Steakhouses'}
# 0     House of Prime Rib          7211               {'alias': 'wine_bars'
# ..                   ...           ...                                 ...
# 998              Bar 217             1          'title': 'Cocktail Bars'}]
# 999  Bristol Bar & Grill            12                   [{'alias': 'bars'
# 999  Bristol Bar & Grill            12                    'title': 'Bars'}
# 999  Bristol Bar & Grill            12             {'alias': 'newamerican'
# 999  Bristol Bar & Grill            12         'title': 'American (New)'}]
#
#      rating
# 0       4.0
# 0       4.0
# 0       4.0
# 0       4.0
# 0       4.0
# ..      ...
# 998     5.0
# 999     2.0
# 999     2.0
# 999     2.0
# 999     2.0
#
# [4450 rows x 4 columns]

# %%
categories_count = categories_data_explode['categories'].value_counts()

# %%
categories_data_explode.categories.value_counts()
# Out:
# {'alias': 'cocktailbars'      157
# 'title': 'Cocktail Bars'}]    139
# 'title': 'Bars'}]             131
# [{'alias': 'bars'             130
# {'alias': 'bars'              115
#                              ...
# 'title': 'Irish Pub'}           1
# 'title': 'Salad'}]              1
# 'title': 'Hawaiian'}]           1
# [{'alias': 'tobaccoshops'       1
# 'title': 'Sports Clubs'}        1
# Name: categories, Length: 430, dtype: int64

# %%
bars_type = categories_data_explode[categories_data_explode.categories.str.contains('title',
                      case=True,na=False)].categories.value_counts()

# %%
bars_type
# Out:
# 'title': 'Cocktail Bars'}]    139
# 'title': 'Bars'}]             131
# 'title': 'Bars'}              114
# 'title': 'American (New)'}    107
# 'title': 'Cocktail Bars'}      98
#                              ...
# 'title': 'Hawaiian'}]           1
# 'title': 'Live/Raw Food'}]      1
# 'title': 'German'}]             1
# 'title': 'Noodles'}             1
# 'title': 'Cigar Bars'}]         1
# Name: categories, Length: 217, dtype: int64

# %%
print('Total number of categories:', len(categories_data_explode[categories_data_explode.categories.str.contains('title',
                      case=True,na=False)].categories.value_counts()))
print('Top 10 categories:')
categories_data_explode[categories_data_explode.categories.str.contains('title',
                      case=True,na=False)].categories.value_counts()[:10]
# Out:
# Total number of categories: 430
# Top 10 categories:
# 'title': 'Cocktail Bars'}]    139
# 'title': 'Bars'}]             131
# 'title': 'Bars'}              114
# 'title': 'American (New)'}    107
# 'title': 'Cocktail Bars'}      98
# 'title': 'Wine Bars'}]         78
# 'title': 'Wine Bars'}          76
# 'title': 'Lounges'}            73
# 'title': 'Sports Bars'}        64
# 'title': 'Lounges'}]           64
# Name: categories, dtype: int64

# %%
bars_json_path = 'bars_data_output.json'
df_b = pd.read_json(bars_json_path)
